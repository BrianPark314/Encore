# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import pandas as pd

# %%
box_office_2020 = pd.read_csv('Data/KC_KOBIS_BOX_OFFIC_MOVIE_INFO_2020.csv', index_col='NO', parse_dates=['OPN_DE'])

# %%
box_office_2020
# Out:
#              MOVIE_NM   DRCTR_NM      MAKR_NM INCME_CMPNY_NM  \
# NO
# 1             남산의 부장들        우민호  (주)하이브미디어코프            NaN
# 2         다만 악에서 구하소서        홍원찬  (주)하이브미디어코프            NaN
# 3                  반도        연상호   (주)영화사레드피터            NaN
# 4                 히트맨        최원섭   베리굿스튜디오(주)            NaN
# 5                  테넷   크리스토퍼 놀란          NaN  워너브러더스 코리아(주)
# ...               ...        ...          ...            ...
# 1981           D컵여자친구        이정석       스마일컨텐츠            NaN
# 1982       F컵 거유의 육덕녀    버드맨 텟페이          NaN    (주)영진크리에이티브
# 1983  F컵 거유의 육덕녀 무삭제판    버드맨 텟페이          NaN            NaN
# 1984  G컵 베이글의 격렬한 플레이        NaN          NaN       (주)빅콘미디어
# 1985  G컵 베이글의 능숙한 몸놀림  아라시야마 미치루          NaN       (주)빅콘미디어
#
#            DISTB_CMPNY_NM     OPN_DE MOVIE_TY_NM MOVIE_STLE_NM NLTY_NM  \
# NO
# 1                  (주)쇼박스 2020-01-22        개봉영화            장편      한국
# 2               (주)씨제이이엔엠 2020-08-05        개봉영화            장편      한국
# ...

# %%
box_office_2020.sort_values('OPN_DE', inplace=True)

# %%
box_office_2020
# Out:
#              MOVIE_NM   DRCTR_NM        MAKR_NM      INCME_CMPNY_NM  \
# NO
# 549              산상수훈        유영의          (주)그란                 NaN
# 637              교회오빠        이호경  KBS,커넥트픽쳐스(주)                 NaN
# 304               알라딘      가이 리치            NaN  월트디즈니컴퍼니코리아 유한책임회사
# 42                기생충        봉준호     (주)바른손이앤에이                 NaN
# 527     천로역정: 천국을 찾아서  로버트 페르난데스            NaN              (재)CBS
# ...               ...        ...            ...                 ...
# 735           네 번째 엄마        윤경식       (주)픽쳐레스크                 NaN
# 1429    숙모의 망사팬티 무삭제판    와카마츠 쇼군            NaN                 NaN
# 655           선샤인 패밀리        김태식           필름라인                 NaN
# 1648  와이프 렌탈 서비스 무삭제판       사이유키            NaN                 NaN
# 1660     욕구불만 아내의 사생활     사노 B사쿠            NaN                 NaN
#
#           DISTB_CMPNY_NM     OPN_DE MOVIE_TY_NM MOVIE_STLE_NM NLTY_NM  \
# NO
# ...

# %%
# %pwd
# Out:
# '/Users/Shark/Encore/Project'

# %%
# Add every font at the specified location
font_dir = ['/Users/Shark/Encore/datas/Noto_Sans_KR']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# ['Noto Sans KR']

# %%
box_office_2020.sort_values('SALES_PRICE', inplace=True)

# %%
import matplotlib.dates as mdates
myFmt = mdates.DateFormatter('%m')

fig, ax = plt.subplots(figsize=(20, 5), layout='constrained')
plt.title('2020년 탑 50 박스오피스 수익', size=30)
plt.xlabel('개봉 날짜 (달)', size=20)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
plt.xlim(pd.datetime(2020,1,1), pd.datetime(2021,1,1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%m'))
plt.gcf().autofmt_xdate()
plt.ylabel('총 박스오피스 수익 (백억 원)', size=20)
plt.axvline(x=pd.datetime(2020, 2,1))
plt.axvline(x=pd.datetime(2020, 5,1))
sns.scatterplot(box_office_2020.tail(50), x='OPN_DE', y='SALES_PRICE')
# Out:
# /var/folders/5l/zhxf24nx12x4g17npl9y29700000gn/T/ipykernel_13816/2462746781.py:8: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   plt.xlim(pd.datetime(2020,1,1), pd.datetime(2021,1,1))
# /var/folders/5l/zhxf24nx12x4g17npl9y29700000gn/T/ipykernel_13816/2462746781.py:10: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.gcf().autofmt_xdate()
# /var/folders/5l/zhxf24nx12x4g17npl9y29700000gn/T/ipykernel_13816/2462746781.py:12: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   plt.axvline(x=pd.datetime(2020, 2,1))
# ...

# %%
nflx_stock = pd.read_csv('Data/NFLX_stock.csv', index_col='날짜', parse_dates=['날짜'])

# %%
nflx_stock
# Out:
#                 종가      오픈      고가      저가    거래량    변동 %
# 날짜
# 2020-12-31  540.73  525.53  545.50  523.15  5.39M   3.08%
# 2020-12-30  524.59  530.13  533.26  523.69  1.88M  -1.18%
# 2020-12-29  530.87  519.90  536.55  515.48  4.02M   2.26%
# 2020-12-28  519.12  516.43  523.66  507.13  2.89M   1.00%
# 2020-12-24  513.97  515.12  519.34  512.21  1.14M  -0.10%
# ...            ...     ...     ...     ...    ...     ...
# 2020-01-08  339.26  331.49  342.70  331.05  7.11M   2.57%
# 2020-01-07  330.75  336.47  336.70  330.30  4.74M  -1.51%
# 2020-01-06  335.83  323.12  336.36  321.20  5.67M   3.05%
# 2020-01-03  325.90  326.78  329.86  325.53  3.80M  -1.19%
# 2020-01-02  329.81  326.10  329.98  324.78  4.35M   1.93%
#
# [253 rows x 6 columns]

# %%
myFmt = mdates.DateFormatter('%m')

fig, ax = plt.subplots(figsize=(20, 5), layout='constrained')
plt.title('2020년 탑 50 박스오피스 수익과 넷플릭스 주식 가격', size=30)
plt.xlabel('개봉 날짜 (달)', size=20)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
plt.xlim(pd.datetime(2020,1,1), pd.datetime(2021,1,1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%m'))
plt.gcf().autofmt_xdate()
plt.ylabel('총 박스오피스 수익 (백억 원)', size=20)
plt.axvline(x=pd.datetime(2020, 2,1))
plt.axvline(x=pd.datetime(2020, 5,1))
sns.scatterplot(box_office_2020.tail(50), x='OPN_DE', y='SALES_PRICE')
ax1=ax.twinx()
ax1.set_ylabel('넷플릭스 주식 가격 ($)', size=20)
sns.lineplot(nflx_stock, x='날짜', y='종가', c='red')
plt.savefig('t50nNetflix')
# Out:
# /var/folders/5l/zhxf24nx12x4g17npl9y29700000gn/T/ipykernel_13816/3880000285.py:7: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   plt.xlim(pd.datetime(2020,1,1), pd.datetime(2021,1,1))
# /var/folders/5l/zhxf24nx12x4g17npl9y29700000gn/T/ipykernel_13816/3880000285.py:9: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.gcf().autofmt_xdate()
# /var/folders/5l/zhxf24nx12x4g17npl9y29700000gn/T/ipykernel_13816/3880000285.py:11: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   plt.axvline(x=pd.datetime(2020, 2,1))
# ...
